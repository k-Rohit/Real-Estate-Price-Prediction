# %%
import pandas as pd
import numpy as np

# %%
flats = pd.read_csv("/content/flats_cleaned.csv")
houses = pd.read_csv("/content/house_cleaned.csv")

# %%
df = pd.concat([flats,houses], ignore_index=True)

# %%
df = df.sample(df.shape[0], ignore_index=True)

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                 3 BHK Flat in Sector 67 Gurgaon          flat
# 1            18 Bedroom House for sale in Suncity         house
# 2            3 Bedroom House for sale in Rosewood         house
# 3   4 Bedroom House for sale in Sector 66 Gurgaon         house
# 4  5 Bedroom House for sale in Sector 108 Gurgaon         house
#
#                society  price  price_per_sqft    area  \
# 0  ireo victory valley   2.95         12110.0  2436.0
# 1          independent   5.50         38194.0  1440.0
# 2          independent   2.95         16388.0  1800.0
# 3   emaar mgf marbella    NaN             NaN     NaN
# 4           sobha city  10.50         14323.0  7331.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 2436(226.31 sq.m.)Built Up...        3         3
# 1                        Plot area 160(133.78 sq.m.)       18        18
# 2  Plot area 1800(167.23 sq.m.)Built Up area: 190...        3         3
# 3  Plot area 350(292.64 sq.m.)Built Up area: 6500...        4         4
# 4                 Built Up area: 7331 (681.07 sq.m.)        5         4
#
#   balcony                                 additionalRoom  \
# 0      3+                        servant room,pooja room
# 1      3+                                   servant room
# 2       3                                     store room
# 3      3+  pooja room,study room,servant room,store room
# 4      3+                                  not available
#
#                                              address  floorNum      facing  \
# 0  Near To Sector 56 Rapid Metro Station Gurgaon,...      14.0       South
# 1                   11111, Suncity, Gurgaon, Haryana       4.0  South-West
# 2  3 Bhk With 3 Bath Independent Villa For Sale A...       2.0  North-West
# 3                Sector 66 Gurgaon, Gurgaon, Haryana       3.0       North
# 4   Sector 109, Sector 108 Gurgaon, Gurgaon, Haryana       1.0        East
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 1   1 to 5 Year Old  ['Sector 54 chowk metro station', 'Sector metr...
# 2  5 to 10 Year Old  ['Sri Radhe Krishna Temple', 'Standard charter...
# 3   0 to 1 Year Old  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 4         undefined  ['Dwarka Sector 21', 'Dwarka Expressway', 'Vas...
#
#                                          description  \
# 0  An excellent 3 bhk residential apartment is fo...
# 1  18 bed room newly built up in 160 yds plot is ...
# 2  Well maintained owner self living 3 bhk with 3...
# 3  This is 350 sq.Yd villa in the heart of the ci...
# 4  Most luxurious property in the vicinity sobha ...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '15 Fan', '1 Exhaust Fan', '5 G...
# 1  ['1 Water Purifier', '22 Fan', '1 Fridge', '1 ...
# 2  ['3 Wardrobe', '1 Water Purifier', '6 Fan', '1...
# 3                                                NaN
# 4                                                NaN
#
#                                             features  \
# 0  ['Water purifier', 'Centrally Air Conditioned'...
# 1  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 2  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4                                                NaN
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4 out of...
# 1  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 2  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 3  ['Environment3 out of 5', 'Safety4 out of 5', ...
# 4  ['Environment4 out of 5', 'Lifestyle4.5 out of...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.to_csv("merged_data.csv")

# %%
# overall_cleaning
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                 3 BHK Flat in Sector 67 Gurgaon          flat
# 1            18 Bedroom House for sale in Suncity         house
# 2            3 Bedroom House for sale in Rosewood         house
# 3   4 Bedroom House for sale in Sector 66 Gurgaon         house
# 4  5 Bedroom House for sale in Sector 108 Gurgaon         house
#
#                society      sector  price  price_per_sqft    area  \
# 0  ireo victory valley   Sector 67   2.95         12110.0  2436.0
# 1          independent     Suncity   5.50         38194.0  1440.0
# 2          independent    Rosewood   2.95         16388.0  1800.0
# 3   emaar mgf marbella   Sector 66    NaN             NaN     NaN
# 4           sobha city  Sector 108  10.50         14323.0  7331.0
#
#                                         areaWithType  bedRoom  bathroom  ...  \
# 0  Super Built up area 2436(226.31 sq.m.)Built Up...        3         3  ...
# 1                        Plot area 160(133.78 sq.m.)       18        18  ...
# 2  Plot area 1800(167.23 sq.m.)Built Up area: 190...        3         3  ...
# 3  Plot area 350(292.64 sq.m.)Built Up area: 6500...        4         4  ...
# 4                 Built Up area: 7331 (681.07 sq.m.)        5         4  ...
#
#                                   additionalRoom  \
# 0                        servant room,pooja room
# 1                                   servant room
# 2                                     store room
# 3  pooja room,study room,servant room,store room
# 4                                  not available
#
#                                              address floorNum      facing  \
# 0  Near To Sector 56 Rapid Metro Station Gurgaon,...     14.0       South
# 1                   11111, Suncity, Gurgaon, Haryana      4.0  South-West
# 2  3 Bhk With 3 Bath Independent Villa For Sale A...      2.0  North-West
# 3                Sector 66 Gurgaon, Gurgaon, Haryana      3.0       North
# 4   Sector 109, Sector 108 Gurgaon, Gurgaon, Haryana      1.0        East
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 1   1 to 5 Year Old  ['Sector 54 chowk metro station', 'Sector metr...
# 2  5 to 10 Year Old  ['Sri Radhe Krishna Temple', 'Standard charter...
# 3   0 to 1 Year Old  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 4         undefined  ['Dwarka Sector 21', 'Dwarka Expressway', 'Vas...
#
#                                          description  \
# 0  An excellent 3 bhk residential apartment is fo...
# 1  18 bed room newly built up in 160 yds plot is ...
# 2  Well maintained owner self living 3 bhk with 3...
# 3  This is 350 sq.Yd villa in the heart of the ci...
# 4  Most luxurious property in the vicinity sobha ...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '15 Fan', '1 Exhaust Fan', '5 G...
# 1  ['1 Water Purifier', '22 Fan', '1 Fridge', '1 ...
# 2  ['3 Wardrobe', '1 Water Purifier', '6 Fan', '1...
# 3                                                NaN
# 4                                                NaN
#
#                                             features  \
# 0  ['Water purifier', 'Centrally Air Conditioned'...
# 1  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 2  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4                                                NaN
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4 out of...
# 1  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 2  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 3  ['Environment3 out of 5', 'Safety4 out of 5', ...
# 4  ['Environment4 out of 5', 'Lifestyle4.5 out of...
#
# [5 rows x 21 columns]

# %%
df['sector'] = df['sector'].str.lower()
df.head()
# Out:
#                                     property_name property_type  \
# 0                 3 BHK Flat in Sector 67 Gurgaon          flat
# 1            18 Bedroom House for sale in Suncity         house
# 2            3 Bedroom House for sale in Rosewood         house
# 3   4 Bedroom House for sale in Sector 66 Gurgaon         house
# 4  5 Bedroom House for sale in Sector 108 Gurgaon         house
#
#                society      sector  price  price_per_sqft    area  \
# 0  ireo victory valley   sector 67   2.95         12110.0  2436.0
# 1          independent     suncity   5.50         38194.0  1440.0
# 2          independent    rosewood   2.95         16388.0  1800.0
# 3   emaar mgf marbella   sector 66    NaN             NaN     NaN
# 4           sobha city  sector 108  10.50         14323.0  7331.0
#
#                                         areaWithType  bedRoom  bathroom  ...  \
# 0  Super Built up area 2436(226.31 sq.m.)Built Up...        3         3  ...
# 1                        Plot area 160(133.78 sq.m.)       18        18  ...
# 2  Plot area 1800(167.23 sq.m.)Built Up area: 190...        3         3  ...
# 3  Plot area 350(292.64 sq.m.)Built Up area: 6500...        4         4  ...
# 4                 Built Up area: 7331 (681.07 sq.m.)        5         4  ...
#
#                                   additionalRoom  \
# 0                        servant room,pooja room
# 1                                   servant room
# 2                                     store room
# 3  pooja room,study room,servant room,store room
# 4                                  not available
#
#                                              address floorNum      facing  \
# 0  Near To Sector 56 Rapid Metro Station Gurgaon,...     14.0       South
# 1                   11111, Suncity, Gurgaon, Haryana      4.0  South-West
# 2  3 Bhk With 3 Bath Independent Villa For Sale A...      2.0  North-West
# 3                Sector 66 Gurgaon, Gurgaon, Haryana      3.0       North
# 4   Sector 109, Sector 108 Gurgaon, Gurgaon, Haryana      1.0        East
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['AIPL Joy Street Mall', 'Golf Course Extensio...
# 1   1 to 5 Year Old  ['Sector 54 chowk metro station', 'Sector metr...
# 2  5 to 10 Year Old  ['Sri Radhe Krishna Temple', 'Standard charter...
# 3   0 to 1 Year Old  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 4         undefined  ['Dwarka Sector 21', 'Dwarka Expressway', 'Vas...
#
#                                          description  \
# 0  An excellent 3 bhk residential apartment is fo...
# 1  18 bed room newly built up in 160 yds plot is ...
# 2  Well maintained owner self living 3 bhk with 3...
# 3  This is 350 sq.Yd villa in the heart of the ci...
# 4  Most luxurious property in the vicinity sobha ...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '15 Fan', '1 Exhaust Fan', '5 G...
# 1  ['1 Water Purifier', '22 Fan', '1 Fridge', '1 ...
# 2  ['3 Wardrobe', '1 Water Purifier', '6 Fan', '1...
# 3                                                NaN
# 4                                                NaN
#
#                                             features  \
# 0  ['Water purifier', 'Centrally Air Conditioned'...
# 1  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 2  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 4                                                NaN
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4 out of...
# 1  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 2  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 3  ['Environment3 out of 5', 'Safety4 out of 5', ...
# 4  ['Environment4 out of 5', 'Lifestyle4.5 out of...
#
# [5 rows x 21 columns]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna                            163
# sector 102                       113
# sector 85                        110
# sector 92                        104
# sector 69                         94
#                                 ...
# anand garden, sector-105           1
# garauli kalan                      1
# ravi nager basai road              1
# lucknow                            1
# old delhi road, opp sector-14      1
# Name: count, Length: 301, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road      163
# sector 102      113
# sector 85       110
# sector 92       104
# sector 69        94
#                ...
# sector 73         3
# sector 110 a      3
# sector 27         3
# sector 15         3
# maruti kunj       3
# Name: count, Length: 131, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 130   4 BHK Flat in New Gurgaon          flat                    sare homes
# 954   4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2382  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 3540  2 BHK Flat in New Gurgaon          flat                   green court
#
#      sector  price  price_per_sqft    area  \
# 130     new   0.85          4786.0  1776.0
# 954     new   4.00         11428.0  3500.0
# 2382    new   0.67          5583.0  1200.0
# 3540    new   0.38          5507.0   690.0
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 130      Super Built up area 1776(165 sq.m.)        4         4  ...
# 954         Carpet area: 3500 (325.16 sq.m.)        4         4  ...
# 2382  Super Built up area 1200(111.48 sq.m.)        2         2  ...
# 3540           Carpet area: 690 (64.1 sq.m.)        2         2  ...
#
#                additionalRoom                        address floorNum  facing  \
# 130             not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 954   study room,servant room  New Gurgaon, Gurgaon, Haryana      4.0     NaN
# 2382            not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 3540            not available  New Gurgaon, Gurgaon, Haryana      7.0     NaN
#
#             agePossession                                    nearbyLocations  \
# 130      5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 954   2027-06-01 00:00:00  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2382      1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3540   Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
#
#                                             description  \
# 130   Located in the popular residential address of ...
# 954   This lovely 4 bhk apartment/flat in new gurgao...
# 2382  Check out this 2 bhk apartment for sale in tak...
# 3540  We are the proud owners of this 2 bhk apartmen...
#
#                                          furnishDetails  \
# 130                                                  []
# 954   ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2382                                                 []
# 3540                                                 []
#
#                                                features rating
# 130                                                 NaN    NaN
# 954   ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 2382  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 3540  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
#
# [4 rows x 21 columns]

# %%
df.loc[955,'sector'] = 'sector 37'
df.loc[2800,'sector'] = 'sector 92'
df.loc[2838,'sector'] = 'sector 90'
df.loc[2857,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 1774                2 BHK Flat in New Palam Vihar          flat
# 2095  2 Bedroom House for sale in New Palam Vihar         house
# 2101                2 BHK Flat in New Palam Vihar          flat
# 2833  3 Bedroom House for sale in New Palam Vihar         house
# 3740                2 BHK Flat in New Palam Vihar          flat
#
#                   society        sector  price  price_per_sqft    area  \
# 1774              my home  new sector 2  0.220          4400.0   500.0
# 2095              my home  new sector 2  0.340         12592.0   270.0
# 2101              my home  new sector 2  0.285          3166.0   900.0
# 2833          independent  new sector 2  1.000          8796.0  1137.0
# 3740  ompee k s residency  new sector 2  1.600         26936.0   594.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1774                     Carpet area: 500 (46.45 sq.m.)        2         2
# 2095                         Plot area 270(25.08 sq.m.)        2         2
# 2101                     Carpet area: 900 (83.61 sq.m.)        2         1
# 2833  Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
# 3740                      Carpet area: 66 (55.18 sq.m.)        2         2
#
#       ... additionalRoom                                            address  \
# 1774  ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 2095  ...  not available         Ez-19 A, New Palam Vihar, Gurgaon, Haryana
# 2101  ...         others         F 150/b, New Palam Vihar, Gurgaon, Haryana
# 2833  ...     pooja room  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...
# 3740  ...  not available                  New Palam Vihar, Gurgaon, Haryana
#
#      floorNum  facing     agePossession  \
# 1774      1.0     NaN   0 to 1 Year Old
# 2095      3.0    West  5 to 10 Year Old
# 2101      2.0     NaN   1 to 5 Year Old
# 2833      1.0   North      10+ Year Old
# 3740      1.0     NaN   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 1774  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2095  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2101  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2833  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3740  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 1774  Cctv surveillance are provided here. There is ...
# 2095  There are availability of various facilities l...
# 2101  2 bhk room with wooden coverd ,1 drawing room,...
# 2833  Ground and first floor, Ground floor: Ground f...
# 3740  We are the proud owners of this 2 bhk apartmen...
#
#                                          furnishDetails  \
# 1774  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 2095  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 2101  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 2833                                                NaN
# 3740                                                NaN
#
#                                           features  \
# 1774                                           NaN
# 2095  ['Water Storage', 'Park', 'Visitor Parking']
# 2101                     ['Water Storage', 'Park']
# 2833                                           NaN
# 3740                                           NaN
#
#                                                  rating
# 1774  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 2095  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2101  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2833  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3740  ['Environment4 out of 5', 'Safety4 out of 5', ...
#
# [5 rows x 21 columns]

# %%
df.loc[[311,1486,3040,3875],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3803, 21)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                           society     sector  price  \
# 136          house                       independent  sector 31   4.25
# 2459          flat                   pareena mi casa  sector 68   1.90
# 489           flat  emaar mgf emerald floors premier  sector 65   2.35
# 790           flat      railway officers rpf society  sector 9a   1.30
# 3176          flat         signature global superbia  sector 95   0.40
#
#       price_per_sqft    area  \
# 136          26235.0  1620.0
# 2459          9227.0  2059.0
# 489          14242.0  1650.0
# 790           5039.0  2580.0
# 3176          6728.0   595.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 136   Plot area 204(170.57 sq.m.)Built Up area: 200 ...        5         5
# 2459                   Carpet area: 2059 (191.29 sq.m.)        3         3
# 489              Super Built up area 1650(153.29 sq.m.)        3         3
# 790                  Built Up area: 2580 (239.69 sq.m.)        4         4
# 3176                  Carpet area: 594.52 (55.23 sq.m.)        2         2
#
#      balcony           additionalRoom  floorNum      facing  \
# 136       3+    store room,pooja room       3.0  North-East
# 2459      3+             servant room       1.0         NaN
# 489        3  study room,servant room       2.0        West
# 790       3+            not available       9.0        East
# 3176       3            not available       2.0         NaN
#
#             agePossession                                    nearbyLocations  \
# 136      5 to 10 Year Old  ['Hanuman Mandir', 'Icici bank ATM', 'State ba...
# 2459   Under Construction  ['Sector 55-56 Metro Station', 'Airia Mall', '...
# 489       1 to 5 Year Old  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
# 790             undefined                                                NaN
# 3176  2026-04-01 00:00:00  ['Huda Metro Station', 'V3S Sapphire Ninety Ma...
#
#                                          furnishDetails  \
# 136   ['10 Wardrobe', '1 Water Purifier', '7 Fan', '...
# 2459                                                 []
# 489   ['8 Fan', '1 Exhaust Fan', '5 Geyser', '14 Lig...
# 790   ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3176                                                 []
#
#                                                features
# 136   ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 2459  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 489   ['Centrally Air Conditioned', 'Water purifier'...
# 790                                                 NaN
# 3176                                                NaN

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
